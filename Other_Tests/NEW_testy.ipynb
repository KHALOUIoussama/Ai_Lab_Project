# %%
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %%
from utils import *

# %%
execute_tests(r'sql1djol\mel', 'MX32401191IL01')
# Out:
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 020302D
# Retester la Palette Voisine 022203D
# --> la *Pire* Palette : 152402B
# -----------------Cas2&3---------------------
# Rien à signaler
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler
# --------------Cas Croisement----------------
# Risque de croisement de courbes avec score : 3.819998034261815
#     Palette Echantillon  Cluster
# 0   022203D           1        2
# 1   022203D           2        2
# 2   022203D           3        2
# 3   022203D           4        2
# 4   022203D           5        2
# 5   022203D           6        2
# 6   022203D           7        2
# 7   022804D           1        2
# 8   022804D           2        2
# 9   022804D           3        2
# ...

# %%
execute_tests(r'sql1djol\mel', 'MX22105037Y101')
# Out:
# ...
#
# -----------------Cas1-----------------------
# Rien à Signaler
# -----------------Cas2&3---------------------
# Rien à signaler
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler
# --------------Cas Croisement----------------
# *Très Grand* Risque de croisement de courbes avec score : 73.22740739588065
#      Palette Echantillon  Cluster
# 0    075901B           1        1
# 1    075901B           2        1
# 2    075901B           3        1
# 3    075901B           4        1
# 4    075901B           5        1
# ..       ...         ...      ...
# 124  112321B           4        1
# 125  112321B           5        1
# 126  112321B           6        1
# 127  112321B           7        1
# 128  112321B           8        1
#
# [129 rows x 3 columns]

# %%
execute_tests(r'sql1djol\mel', 'MX124012721XC01')
# Out:
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 000210C
# Retester la Palette Hors Norme 001711C
# Retester la Palette Hors Norme 003112C
# Retester la Palette Hors Norme 004513C
# Retester la Palette Hors Norme 010114C
# Retester la Palette Hors Norme 011315C
# Retester la Palette Hors Norme 012716C
# Retester la Palette Hors Norme 013717C
# Retester la Palette Hors Norme 014318C
# Retester la Palette Hors Norme 215801C
# Retester la Palette Hors Norme 221002C
# Retester la Palette Hors Norme 222403C
# Retester la Palette Hors Norme 223804C
# Retester la Palette Hors Norme 230506C
# Retester la Palette Hors Norme 232007C
# Retester la Palette Hors Norme 233408C
# Retester la Palette Hors Norme 234709C
# --> la *Pire* Palette : 152402B
# -----------------Cas2&3---------------------
# -> Faire retests
# Palette 2 de la Batch 222403C est au dessous de la limite MH
# Palette 1 de la Batch 230506C est au dessous de la limite MH
# ...

# %%
execute_tests(r'sql1djol\mel', 'MX124020462I01')
# Out:
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 060801D
# Retester la Palette Hors Norme 064304D
# Retester la Palette Hors Norme 071006A
# Retester la Palette Hors Norme 074509A
# Retester la Palette Voisine 063103D
# Retester la Palette Voisine 072207A
# Retester la Palette Voisine 073308A
# --> la *Pire* Palette : 152402B
# -----------------Cas2&3---------------------
# -> Faire retests
# Palette 4 de la Batch 071006A est au dessus de la limite MH
# Palette 5 de la Batch 071006A est au dessus de la limite MH
# Palette 6 de la Batch 071006A est au dessus de la limite MH
# Palette 7 de la Batch 071006A est au dessus de la limite MH
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler

# %%
execute_tests(r'sql1djol\mel','MX22309119YN01')
# Out:
# ...
#
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 095801A
# Retester la Palette Hors Norme 100602A
# --> la *Pire* Palette : 152402B
# -----------------Cas2&3---------------------
# -> Remélange seul
# Palette 1 de la Batch 095801A est au dessous de la limite MH
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler
# --------------Cas Croisement----------------
# *Très Grand* Risque de croisement de courbes avec score : 11.393419179837542
#     Palette Echantillon  Cluster
# 0   095801A           1        1
# 1   095801A           2        1
# 2   095801A           3        1
# 3   095801A           4        1
# 4   095801A           5        1
# ..      ...         ...      ...
# 77  115915A           1        2
# 78  115915A           2        2
# ...

# %%
execute_tests('sqlmelpjol','MX224012014MG01')
# Out:
# ...
#
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 150502A
# Retester la Palette Hors Norme 155208A
# Retester la Palette Hors Norme 161511A
# Retester la Palette Hors Norme 162512A
# Retester la Palette Hors Norme 163313A
# Retester la Palette Voisine 160009A
# --> la *Pire* Palette : 162512A
# -----------------Cas2&3---------------------
# Faire retests
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler
# --------------Cas Croisement----------------
# *Très Grand* Risque de croisement de courbes avec score : 11.799809991569363
#      Palette Echantillon  Cluster
# 0    145801A           1        2
# 1    145801A           2        2
# 2    145801A           3        2
# 3    145801A           4        2
# 4    145801A           5        2
# ...

# %%
execute_tests('sqlmelpjol','MX2240731102001')
# Out:
# -----------------Cas1-----------------------
# Rien à Signaler
# -----------------Cas2&3---------------------
# -> Faire retests
# Palette 3 de la Batch 113105B est au dessous de la limite MH
# Palette 7 de la Batch 114006B est au dessous de la limite MH
# Palette 3 de la Batch 120808B est au dessous de la limite MH
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Cas 7 : Envoyer l'échantillon 3 de la Palette 113105B en REMILL
# Cas 7 : Envoyer l'échantillon 7 de la Palette 114006B en REMILL
# Cas 7 : Envoyer l'échantillon 3 de la Palette 120808B en REMILL
# Envoyer E-mail à JL-PLT Intervention pour les aviser

# %%
execute_tests('sqlmelpjol','MX2240729111701')
# Out:
# -----------------Cas1-----------------------
# Rien à Signaler
# -----------------Cas2&3---------------------
# -> Faire retests
# Palette 7 de la Batch 112101A est au dessous de la limite MH
# Palette 9 de la Batch 112101A est au dessous de la limite MH
# Palette 2 de la Batch 113702A est au dessous de la limite MH
# Palette 1 de la Batch 114503A est au dessous de la limite MH
# Palette 4 de la Batch 114503A est au dessous de la limite MH
# Palette 5 de la Batch 114503A est au dessous de la limite MH
# Palette 6 de la Batch 114503A est au dessous de la limite MH
# Palette 7 de la Batch 114503A est au dessous de la limite MH
# Palette 8 de la Batch 114503A est au dessous de la limite MH
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# ...

# %%
execute_tests('sqlmelpjol','MX224043015W501')
# Out:
# !!!!!!!!!!!!!!!!!!! TMA !!!!!!!!!!!!!!!!!!!!
#
# -----------------Cas1-----------------------
# Retester la Palette Hors Norme 151501B
# Retester la Palette Hors Norme 152402B
# --> la *Pire* Palette : 152402B
# -----------------Cas2&3---------------------
# Rien à signaler
# -----------------Cas4-----------------------
# Rien à signaler
# -----------------Cas5-----------------------
# Rien à signaler
# -----------------Cas6-----------------------
# Rien à Signaler
# -----------------Cas7-----------------------
# Rien à Signaler
